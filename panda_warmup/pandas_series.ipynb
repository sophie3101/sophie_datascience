# %%
import pandas ad pd
# Out:
# The kernel failed to start as the Python Environment 'ds (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %% [markdown]
# Dict TO Series

# %%
a_dict={'a': 100, 'b': 200, 'c': 300, 'd': 400, 'e': 800}
pd.DataFrame(a_dict)
